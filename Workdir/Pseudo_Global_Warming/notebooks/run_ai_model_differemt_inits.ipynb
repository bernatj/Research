# %%
import sys
sys.path.append('/home/bernatj/jbayesevt')

import numpy as np
from pathlib import Path
import xarray as xr
import os
import datetime
from earth2mip import inference_ensemble, registry
from earth2mip.networks import get_model
from earth2mip.initial_conditions import cds
from earth2mip.inference_ensemble import run_basic_inference
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from bayesevt._src.data.ics import LocalDataSourceXArray

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
model_name = "pangu_6" # "fcnv2_sm"
model = f"e2mip://{model_name}"
device = "cuda:1"

# %%
time_loop  = get_model(
    model=model,
    device=device,
)
channel_names = time_loop.in_channel_names

# %%
#config 

file_format = 'grib'
outputdir="/home/bernatj/Data/ai-forecasts/fcst/"

#we want to run our model for different dates
t0_i = datetime.datetime(2022,7,1,0)
t0_f = datetime.datetime(2022,7,31,18)
delta_h = 6
# number of forecast steps
num_steps = 4 * 15 # 6h intervals
#vars_to_save = ['t2m','t850','msl','tcwv','z500','u100m','v100m','u10m','v10m']
vars_to_save = ['t2m','z500']

init_times = []
current_time = t0_i
while current_time <= t0_f:
    init_times.append(current_time)
    current_time += datetime.timedelta(hours=delta_h)

# %%
for t0 in init_times:
    print(t0)
# Out:
# 2022-07-01 00:00:00
# 2022-07-01 06:00:00
# 2022-07-01 12:00:00
# 2022-07-01 18:00:00
# 2022-07-02 00:00:00
# 2022-07-02 06:00:00
# 2022-07-02 12:00:00
# 2022-07-02 18:00:00
# 2022-07-03 00:00:00
# 2022-07-03 06:00:00
# 2022-07-03 12:00:00
# 2022-07-03 18:00:00
# 2022-07-04 00:00:00
# 2022-07-04 06:00:00
# 2022-07-04 12:00:00
# 2022-07-04 18:00:00
# 2022-07-05 00:00:00
# 2022-07-05 06:00:00
# 2022-07-05 12:00:00
# 2022-07-05 18:00:00
# 2022-07-06 00:00:00
# 2022-07-06 06:00:00
# 2022-07-06 12:00:00
# 2022-07-06 18:00:00
# 2022-07-07 00:00:00
# 2022-07-07 06:00:00
# 2022-07-07 12:00:00
# 2022-07-07 18:00:00
# 2022-07-08 00:00:00
# 2022-07-08 06:00:00
# 2022-07-08 12:00:00
# 2022-07-08 18:00:00
# 2022-07-09 00:00:00
# 2022-07-09 06:00:00
# 2022-07-09 12:00:00
# 2022-07-09 18:00:00
# 2022-07-10 00:00:00
# 2022-07-10 06:00:00
# 2022-07-10 12:00:00
# 2022-07-10 18:00:00
# 2022-07-11 00:00:00
# 2022-07-11 06:00:00
# 2022-07-11 12:00:00
# 2022-07-11 18:00:00
# 2022-07-12 00:00:00
# 2022-07-12 06:00:00
# 2022-07-12 12:00:00
# 2022-07-12 18:00:00
# 2022-07-13 00:00:00
# 2022-07-13 06:00:00
# 2022-07-13 12:00:00
# 2022-07-13 18:00:00
# 2022-07-14 00:00:00
# 2022-07-14 06:00:00
# 2022-07-14 12:00:00
# 2022-07-14 18:00:00
# 2022-07-15 00:00:00
# 2022-07-15 06:00:00
# 2022-07-15 12:00:00
# 2022-07-15 18:00:00
# 2022-07-16 00:00:00
# 2022-07-16 06:00:00
# 2022-07-16 12:00:00
# 2022-07-16 18:00:00
# 2022-07-17 00:00:00
# 2022-07-17 06:00:00
# 2022-07-17 12:00:00
# 2022-07-17 18:00:00
# 2022-07-18 00:00:00
# 2022-07-18 06:00:00
# 2022-07-18 12:00:00
# 2022-07-18 18:00:00
# 2022-07-19 00:00:00
# 2022-07-19 06:00:00
# 2022-07-19 12:00:00
# 2022-07-19 18:00:00
# 2022-07-20 00:00:00
# 2022-07-20 06:00:00
# 2022-07-20 12:00:00
# 2022-07-20 18:00:00
# 2022-07-21 00:00:00
# 2022-07-21 06:00:00
# 2022-07-21 12:00:00
# 2022-07-21 18:00:00
# 2022-07-22 00:00:00
# 2022-07-22 06:00:00
# 2022-07-22 12:00:00
# 2022-07-22 18:00:00
# 2022-07-23 00:00:00
# 2022-07-23 06:00:00
# 2022-07-23 12:00:00
# 2022-07-23 18:00:00
# 2022-07-24 00:00:00
# 2022-07-24 06:00:00
# 2022-07-24 12:00:00
# 2022-07-24 18:00:00
# 2022-07-25 00:00:00
# 2022-07-25 06:00:00
# 2022-07-25 12:00:00
# 2022-07-25 18:00:00
# 2022-07-26 00:00:00
# 2022-07-26 06:00:00
# 2022-07-26 12:00:00
# 2022-07-26 18:00:00
# 2022-07-27 00:00:00
# 2022-07-27 06:00:00
# 2022-07-27 12:00:00
# 2022-07-27 18:00:00
# 2022-07-28 00:00:00
# 2022-07-28 06:00:00
# 2022-07-28 12:00:00
# 2022-07-28 18:00:00
# 2022-07-29 00:00:00
# 2022-07-29 06:00:00
# 2022-07-29 12:00:00
# 2022-07-29 18:00:00
# 2022-07-30 00:00:00
# 2022-07-30 06:00:00
# 2022-07-30 12:00:00
# 2022-07-30 18:00:00
# 2022-07-31 00:00:00
# 2022-07-31 06:00:00
# 2022-07-31 12:00:00
# 2022-07-31 18:00:00

# %%
def do_forecast(channel_names, file_paths,  pressure_name='isobaricInhPa', engine='netcdf4'):
    
    #get the init data
    data_source_xr = LocalDataSourceXArray(
    channel_names=channel_names,
    file_paths=file_paths,
    pressure_name=pressure_name, 
    name_convention="short_name",
    engine=engine, 
    )

    #run the model
    forecast = run_basic_inference(
    time_loop, 
    n=num_steps, 
    data_source=data_source_xr, 
    time=t0
    )

    return forecast

# %%
if file_format == 'grib':
    ending='grib'
    engine='cfgrib'
elif file_format == 'netcdf':
    ending='nc'
    engine='netcdf4'

# %%
for t0 in init_times:

    yyyymmddhh = t0.strftime('%Y%m%d%H')
    
    file_paths = [  
    f"/home/bernatj/Data/ai-forecasts/input/{file_format}/{yyyymmddhh}/fcnv2_sl_PGW_multimodel_{yyyymmddhh}.{ending}",
    f"/home/bernatj/Data/ai-forecasts/input/{file_format}/{yyyymmddhh}/fcnv2_pl_PGW_multimodel_{yyyymmddhh}.{ending}"
    ]
    
    #run one forecast
    forecast = do_forecast(channel_names, file_paths, engine=engine)

    #store the data
    os.makedirs(outputdir+'/'+yyyymmddhh, exist_ok=True)
    for var in vars_to_save:
        forecast.sel(channel=var).squeeze().drop_vars('channel').to_dataset(name=var).to_netcdf(outputdir+f'{yyyymmddhh}/{var}_fcnv2_PGW_multimodel_{yyyymmddhh}.nc')

    print(f'finished forecast for init {t0}')
# Out:
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-01
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-01
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 182
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-01 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-01T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-01T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 182
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-01 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-01T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-01T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 182
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-01 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-01T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-01T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 182
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-01 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-02
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-02
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 183
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-02 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-02T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-02T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 183
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-02 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-02T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-02T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 183
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-02 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-02T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-02T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 183
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-02 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-03
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-03
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 184
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-03 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-03T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-03T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 184
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-03 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-03T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-03T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 184
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-03 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-03T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-03T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 184
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-03 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-04
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-04
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 185
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-04 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-04T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-04T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 185
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-04 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-04T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-04T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 185
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-04 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-04T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-04T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 185
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-04 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-05
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-05
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 186
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-05 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-05T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-05T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 186
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-05 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-05T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-05T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 186
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-05 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-05T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-05T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 186
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-05 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-06
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-06
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 187
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-06 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-06T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-06T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 187
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-06 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-06T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-06T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 187
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-06 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-06T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-06T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 187
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-06 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-07
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-07
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 188
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-07 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-07T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-07T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 188
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-07 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-07T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-07T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 188
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-07 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-07T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-07T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 188
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-07 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-08
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-08
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 189
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-08 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-08T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-08T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 189
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-08 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-08T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-08T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 189
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-08 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-08T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-08T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 189
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-08 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-09
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-09
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 190
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
# ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-29 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-30
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-30
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 211
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-30 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-30T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-30T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 211
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-30 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-30T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-30T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 211
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-30 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2022-07-30T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2022-07-30T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 211
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2022-07-30 18:00:00
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/miniconda3/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/bernatj/Data/ai-forecasts/input/netcdf/2022073100/fcnv2_sl_PGW_multimodel_2022073100.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '9cde9827-9b7a-452a-8c2b-6d03893f232c']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 11
#       5 file_paths = [
#       6 f"/home/bernatj/Data/ai-forecasts/input/{file_format}/{yyyymmddhh}/fcnv2_sl_PGW_multimodel_{yyyymmddhh}.{ending}",
#       7 f"/home/bernatj/Data/ai-forecasts/input/{file_format}/{yyyymmddhh}/fcnv2_pl_PGW_multimodel_{yyyymmddhh}.{ending}"
#       8 ]
#      10 #run one forecast
# ---> 11 forecast = do_forecast(channel_names, file_paths, engine=engine)
#      13 #store the data
#      14 os.makedirs(outputdir+'/'+yyyymmddhh, exist_ok=True)
#
# Cell In[6], line 13, in do_forecast(channel_names, file_paths, pressure_name, engine)
#       4 data_source_xr = LocalDataSourceXArray(
#       5 channel_names=channel_names,
#       6 file_paths=file_paths,
#    (...)
#       9 engine=engine,
#      10 )
#      12 #run the model
# ---> 13 forecast = run_basic_inference(
#      14 time_loop,
#      15 n=num_steps,
#      16 data_source=data_source_xr,
#      17 time=t0
#      18 )
#      20 return forecast
#
# File ~/miniconda3/envs/bayesevt_ai/lib/python3.10/site-packages/earth2mip/inference_ensemble.py:282, in run_basic_inference(model, n, data_source, time)
#     274 def run_basic_inference(
#     275     model: time_loop.TimeLoop,
#     276     n: int,
#     277     data_source: Any,
#     278     time: datetime,
#     279 ):
#     280     """Run a basic inference"""
# --> 282     x = initial_conditions.get_initial_condition_for_model(model, data_source, time)
#     284     arrays = []
#     285     times = []
#
# File ~/miniconda3/envs/bayesevt_ai/lib/python3.10/site-packages/earth2mip/initial_conditions/__init__.py:109, in get_initial_condition_for_model(time_loop, data_source, time)
#     106 def get_initial_condition_for_model(
#     107     time_loop: time_loop.TimeLoop, data_source: base.DataSource, time: datetime
#     108 ) -> torch.Tensor:
# --> 109     return get_data_from_source(
#     110         data_source,
#     111         time,
#     112         time_loop.in_channel_names,
#     113         time_loop.grid,
#     114         time_loop.n_history_levels,
#     115         time_loop.history_time_step,
#     116         time_loop.device,
#     117         time_loop.dtype,
#     118     )
#
# File ~/miniconda3/envs/bayesevt_ai/lib/python3.10/site-packages/earth2mip/initial_conditions/__init__.py:86, in get_data_from_source(data_source, time, channel_names, grid, n_history_levels, time_step, device, dtype)
#      84 for i in range(n_history_levels - 1, -1, -1):
#      85     time_to_get = time - i * dt
# ---> 86     arr = data_source[time_to_get]
#      87     expected_shape = (len(data_source.channel_names), *data_source.grid.shape)
#      88     arrays.append(arr)
#
# File ~/jbayesevt/bayesevt/_src/data/ics.py:135, in LocalDataSourceXArray.__getitem__(self, time)
#     132 channel_codes = parse_all_variables(self.channel_names)
#     134 # 2) load data based on codes
# --> 135 ds: xr.Dataset = xr.open_mfdataset(paths=self.file_paths, engine=self.engine, combine="by_coords")
#     137 # 3) select time coordinate
#     138 try:
#
# File ~/miniconda3/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/backends/api.py:1054, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1051     open_ = open_dataset
#    1052     getattr_ = getattr
# -> 1054 datasets = [open_(p, **open_kwargs) for p in paths]
#    1055 closers = [getattr_(ds, "_close") for ds in datasets]
#    1056 if preprocess is not None:
#
# File ~/miniconda3/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/backends/api.py:1054, in <listcomp>(.0)
#    1051     open_ = open_dataset
#    1052     getattr_ = getattr
# -> 1054 datasets = [open_(p, **open_kwargs) for p in paths]
#    1055 closers = [getattr_(ds, "_close") for ds in datasets]
#    1056 if preprocess is not None:
#
# File ~/miniconda3/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/backends/api.py:571, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     559 decoders = _resolve_decoders_kwargs(
#     560     decode_cf,
#     561     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     567     decode_coords=decode_coords,
#     568 )
#     570 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 571 backend_ds = backend.open_dataset(
#     572     filename_or_obj,
#     573     drop_variables=drop_variables,
#     574     **decoders,
#     575     **kwargs,
#     576 )
#     577 ds = _dataset_from_backend_dataset(
#     578     backend_ds,
#     579     filename_or_obj,
#    (...)
#     589     **kwargs,
#     590 )
#     591 return ds
#
# File ~/miniconda3/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:646, in NetCDF4BackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, lock, autoclose)
#     625 def open_dataset(  # type: ignore[override]  # allow LSP violation, not supporting **kwargs
#     626     self,
#     627     filename_or_obj: str | os.PathLike[Any] | BufferedIOBase | AbstractDataStore,
#    (...)
#     643     autoclose=False,
#     644 ) -> Dataset:
#     645     filename_or_obj = _normalize_path(filename_or_obj)
# --> 646     store = NetCDF4DataStore.open(
#     647         filename_or_obj,
#     648         mode=mode,
#     649         format=format,
#     650         group=group,
#     651         clobber=clobber,
#     652         diskless=diskless,
#     653         persist=persist,
#     654         lock=lock,
#     655         autoclose=autoclose,
#     656     )
#     658     store_entrypoint = StoreBackendEntrypoint()
#     659     with close_on_error(store):
#
# File ~/miniconda3/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:409, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     403 kwargs = dict(
#     404     clobber=clobber, diskless=diskless, persist=persist, format=format
#     405 )
#     406 manager = CachingFileManager(
#     407     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     408 )
# --> 409 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File ~/miniconda3/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:356, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     354 self._group = group
#     355 self._mode = mode
# --> 356 self.format = self.ds.data_model
#     357 self._filename = self.ds.filepath()
#     358 self.is_remote = is_remote_uri(self._filename)
#
# File ~/miniconda3/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:418, in NetCDF4DataStore.ds(self)
#     416 @property
#     417 def ds(self):
# --> 418     return self._acquire()
#
# File ~/miniconda3/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:412, in NetCDF4DataStore._acquire(self, needs_lock)
#     411 def _acquire(self, needs_lock=True):
# --> 412     with self._manager.acquire_context(needs_lock) as root:
#     413         ds = _nc4_require_group(root, self._group, self._mode)
#     414     return ds
#
# File ~/miniconda3/envs/bayesevt_ai/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniconda3/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager.acquire_context(self, needs_lock)
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File ~/miniconda3/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/backends/file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File src/netCDF4/_netCDF4.pyx:2469, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:2028, in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/bernatj/Data/ai-forecasts/input/netcdf/2022073100/fcnv2_sl_PGW_multimodel_2022073100.nc'

# %%
for t0 in init_times:

    yyyymmddhh = t0.strftime('%Y%m%d%H')
    
    file_paths = [  
    f"/home/bernatj/Data/ai-forecasts/input/{file_format}/{yyyymmddhh}/fcnv2_sl_{yyyymmddhh}.{ending}",
    f"/home/bernatj/Data/ai-forecasts/input/{file_format}/{yyyymmddhh}/fcnv2_pl_{yyyymmddhh}.{ending}"
    ]
    
    #run one forecast
    forecast = do_forecast(channel_names, file_paths, engine=engine)

    #store the data
    os.makedirs(outputdir+'/'+yyyymmddhh, exist_ok=True)
    for var in vars_to_save:
        forecast.sel(channel=var).squeeze().drop_vars('channel').to_dataset(name=var).to_netcdf(outputdir+f'{yyyymmddhh}/{var}_fcnv2_{yyyymmddhh}.nc')

    print(f'finished forecast for init {t0}')
# Out:
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-25
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-25
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-25 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-25T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-25T06:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-25 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-25T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-25T12:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-25 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-25T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-25T18:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-25 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-26
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-26
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-26 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-26T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-26T06:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-26 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-26T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-26T12:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-26 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-26T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-26T18:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-26 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-27
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-27
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-27 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-27T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-27T06:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-27 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-27T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-27T12:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-27 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-27T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-27T18:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-27 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-28
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-28
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-28 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-28T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-28T06:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-28 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-28T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-28T12:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-28 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-28T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-28T18:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-28 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-29
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-29
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-29 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-29T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-29T06:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-29 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-29T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-29T12:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-29 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-29T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-29T18:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-29 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-30
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-30
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-30 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-30T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-30T06:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-30 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-30T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-30T12:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-30 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-30T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-30T18:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-30 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-31
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-31
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-31 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-31T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-31T06:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-31 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-31T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-31T12:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-31 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-10-31T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-10-31T18:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-10-31 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-11-01
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-11-01
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-11-01 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-11-01T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-11-01T06:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-11-01 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-11-01T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-11-01T12:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-11-01 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-11-01T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-11-01T18:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-11-01 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-11-02
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-11-02
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-11-02 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-11-02T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-11-02T06:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-11-02 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-11-02T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-11-02T12:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-11-02 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-11-02T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-11-02T18:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-11-02 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-11-03
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-11-03
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-11-03 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-11-03T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-11-03T06:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-11-03 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-11-03T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-11-03T12:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-11-03 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-11-03T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-11-03T18:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-11-03 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-11-04
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-11-04
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-11-04 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-11-04T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-11-04T06:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-11-04 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-11-04T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-11-04T12:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-11-04 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2023-11-04T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B 2023-11-04T18:00:00
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2023-11-04 18:00:00
