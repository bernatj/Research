# %%
import xarray as xr
import matplotlib as mpl
import numpy as np

# %%
#read monthly Temperature and relative humidity data
ds0 = xr.open_dataset('/home/bernatj/Data/ai-forecasts/input/grib/fcnv2sm_pl_20180731.grib', engine='cfgrib')
ds1 = xr.open_dataset('/home/bernatj/Data/ai-forecasts/input/netcdf/fcnv2sm_pl_PGW_ec-earth3-veg_20180731.nc')
ds2 = xr.open_dataset('/home/bernatj/Data/ai-forecasts/input/netcdf/fcnv2sm_pl_PGW_ec-earth3-veg_v2_20180731.nc')

diff1 = ds0 - ds1
diff2 = ds0 - ds2
diff3 = ds2 - ds1

# %%
ds2.z.sel(isobaricInhPa=500).plot()

# %%
diff3.z.sel(isobaricInhPa=925).plot()

# %%
(z_diff/9.806).sel(level=600).plot(vmin=-50,vmax=50,cmap='RdBu_r')
()
# Out:
# ()
